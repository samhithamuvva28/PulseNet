# %% [markdown]
# Determing the threshold for the Time Interval across all participants:

# %%
import os
import pandas as pd

# Defining the main directory containing the train set participant folders
TRAIN_DIR = '/Users/nandana_hemanth/Documents/Semester II/DATA 245/Project/Dataset/child-mind-institute-problematic-internet-use/series_train.parquet'

# Storing interval statistics for each participant
interval_stats = []

# Iterating over each participant's folder
for folder in os.listdir(TRAIN_DIR):
    participant_path = os.path.join(TRAIN_DIR, folder)
    if os.path.isdir(participant_path):
        # Printing the current participant being processed
        print(f"Processing participant: {folder}")
        
        # Loading participant's data
        file_path = os.path.join(participant_path, 'part-0.parquet')
        series_data = pd.read_parquet(file_path)
        
        # Step 1: Converting to Continuous Time Scale if needed
        if 'day_time' not in series_data.columns:
            series_data['time_of_day_hours'] = series_data['time_of_day'] / 1e9 / 3600  # Convert to hours
            series_data['day_time'] = series_data['relative_date_PCIAT'] + (series_data['time_of_day_hours'] / 24)
        
        # Step 2: Calculating Time Differences in Seconds
        series_data['time_diff'] = (series_data['day_time'].diff() * 86400).round(0)  # Convert to seconds
        
        # Step 3: Collecting Statistics for Time Differences
        interval_stats.append({
            'participant_id': folder,
            'mean_interval': series_data['time_diff'].mean(),
            'median_interval': series_data['time_diff'].median(),
            '25th_percentile': series_data['time_diff'].quantile(0.25),
            '75th_percentile': series_data['time_diff'].quantile(0.75),
            '90th_percentile': series_data['time_diff'].quantile(0.90),
            'max_interval': series_data['time_diff'].max()
        })

# Creating a DataFrame with the interval statistics for analysis
interval_df = pd.DataFrame(interval_stats)
print("Interval Statistics Across Participants:\n", interval_df.describe())
# Out:
# Processing participant: id=0d01bbf2
# Processing participant: id=cefdb7fe
# Processing participant: id=58391429
# Processing participant: id=2ca2206f
# Processing participant: id=19455336
# Processing participant: id=ca33a5e7
# Processing participant: id=92bb8516
# Processing participant: id=2812951b
# Processing participant: id=6b6467f4
# Processing participant: id=9d6b1410
# Processing participant: id=22c72c4e
# Processing participant: id=b3b200af
# Processing participant: id=ebf30e46
# Processing participant: id=2a0b8386
# Processing participant: id=71c1b1d2
# Processing participant: id=e683d2c9
# Processing participant: id=bebff291
# Processing participant: id=d4d2f272
# Processing participant: id=81d3ab22
# Processing participant: id=051680a0
# Processing participant: id=1aff6762
# Processing participant: id=a0522c83
# Processing participant: id=b447e66d
# Processing participant: id=90161e10
# Processing participant: id=adbd6839
# Processing participant: id=3e5d5b58
# Processing participant: id=cd68643b
# Processing participant: id=af4f064e
# Processing participant: id=554e46e9
# Processing participant: id=8f21c613
# Processing participant: id=3826be66
# Processing participant: id=2898269f
# Processing participant: id=43f5d3c5
# Processing participant: id=76fb4afb
# Processing participant: id=fc2c2c08
# Processing participant: id=1837456f
# Processing participant: id=4bc2bee9
# Processing participant: id=a402c6c8
# Processing participant: id=035c96dd
# Processing participant: id=29587a31
# Processing participant: id=ab16a20d
# Processing participant: id=fa34f945
# Processing participant: id=c9600298
# Processing participant: id=070386b2
# Processing participant: id=91656d27
# Processing participant: id=3f1f23e7
# Processing participant: id=e46417a7
# Processing participant: id=7b0a4060
# Processing participant: id=5f574f3d
# Processing participant: id=8c1f9196
# Processing participant: id=5e57bd12
# Processing participant: id=d3da09e8
# Processing participant: id=4a9f92ca
# Processing participant: id=7e87087b
# Processing participant: id=8a77c3e9
# Processing participant: id=5779f2e9
# Processing participant: id=93904b23
# Processing participant: id=98413061
# Processing participant: id=fa633e39
# Processing participant: id=c3d46daf
# Processing participant: id=d8037389
# Processing participant: id=b7c410a9
# Processing participant: id=bc66f41d
# Processing participant: id=6a4df6ff
# Processing participant: id=641697e6
# Processing participant: id=089a6b19
# Processing participant: id=1f65fa82
# Processing participant: id=66f619e3
# Processing participant: id=c79039af
# Processing participant: id=0bd89878
# Processing participant: id=cb2752bc
# Processing participant: id=1c5ba087
# Processing participant: id=54945f30
# Processing participant: id=5132511c
# Processing participant: id=0a431608
# Processing participant: id=b1de4423
# Processing participant: id=a3bd8858
# Processing participant: id=e1ccc3d1
# Processing participant: id=94a1053b
# Processing participant: id=fa9a0add
# Processing participant: id=09331bb8
# Processing participant: id=18b8b2f6
# Processing participant: id=045a0a94
# Processing participant: id=e21255e2
# Processing participant: id=930c567c
# Processing participant: id=fd028ecc
# Processing participant: id=e51193d1
# Processing participant: id=9d65adbf
# Processing participant: id=1cd37b36
# Processing participant: id=a0182b17
# Processing participant: id=87050a09
# Processing participant: id=649ff6d9
# Processing participant: id=6f5677b7
# Processing participant: id=6e1d28b6
# Processing participant: id=4d5a8ce7
# Processing participant: id=9ebb73c7
# Processing participant: id=e0db55b1
# Processing participant: id=f47a67cc
# Processing participant: id=7494989e
# Processing participant: id=0a418b57
# Processing participant: id=807d8908
# Processing participant: id=5ed5f205
# Processing participant: id=c9e419e7
# Processing participant: id=eef79620
# Processing participant: id=5b2c9b83
# Processing participant: id=966161e7
# Processing participant: id=687c85e7
# Processing participant: id=9e171735
# Processing participant: id=e328a032
# Processing participant: id=b3f5c066
# Processing participant: id=23e024bd
# Processing participant: id=f9384fa2
# Processing participant: id=408bed19
# Processing participant: id=13eee030
# Processing participant: id=b4e69f09
# Processing participant: id=a5710c0a
# Processing participant: id=33fe1b04
# Processing participant: id=cfcf9dc9
# Processing participant: id=893293dd
# Processing participant: id=3d3dd3ae
# Processing participant: id=2760be91
# Processing participant: id=4570c8b8
# Processing participant: id=e3bce7e1
# Processing participant: id=1eea8df2
# Processing participant: id=35fa2ebf
# Processing participant: id=56cb7161
# Processing participant: id=ed0b3906
# Processing participant: id=48db8ecf
# Processing participant: id=428970d4
# Processing participant: id=3c2cf08e
# Processing participant: id=e9d94c4e
# Processing participant: id=12a607f6
# Processing participant: id=8cab7bc4
# Processing participant: id=eeedcd5e
# Processing participant: id=8f9c03c6
# Processing participant: id=a4530b41
# Processing participant: id=01085eb3
# Processing participant: id=c829500d
# Processing participant: id=8a4e5d1a
# Processing participant: id=f028534c
# Processing participant: id=37995242
# Processing participant: id=e9ca5586
# Processing participant: id=8c6c52a2
# Processing participant: id=64b4005d
# Processing participant: id=00f332d1
# Processing participant: id=7b543871
# Processing participant: id=4decbcd8
# Processing participant: id=98ed2153
# Processing participant: id=c6313b18
# Processing participant: id=d6251195
# Processing participant: id=221e37e0
# Processing participant: id=1b5b34bc
# Processing participant: id=1aae1de3
# Processing participant: id=9f9be55c
# Processing participant: id=bdbff28b
# Processing participant: id=7f2715b4
# Processing participant: id=ee2bf575
# Processing participant: id=9d1b2d2c
# Processing participant: id=6c2edc91
# Processing participant: id=87af775e
# Processing participant: id=f7b1374e
# Processing participant: id=1e87baed
# Processing participant: id=697c41d7
# Processing participant: id=c294b507
# Processing participant: id=c3a86e3e
# Processing participant: id=f1baae47
# Processing participant: id=cda90e9e
# Processing participant: id=d506f4c7
# Processing participant: id=2e17c497
# Processing participant: id=397efe7a
# Processing participant: id=5e55e9fd
# Processing participant: id=948a7025
# Processing participant: id=2e5f5207
# Processing participant: id=f9334e08
# Processing participant: id=721ea536
# Processing participant: id=429cc266
# Processing participant: id=7f44236f
# Processing participant: id=ad9f821d
# Processing participant: id=6e9beaee
# Processing participant: id=1314bc8c
# Processing participant: id=15f2e240
# Processing participant: id=0bfe4fc9
# Processing participant: id=26190ddd
# Processing participant: id=9fa5cdfd
# Processing participant: id=224fc39a
# Processing participant: id=4a4a0f78
# Processing participant: id=351cd4ec
# Processing participant: id=6826f0be
# Processing participant: id=c3dde859
# Processing participant: id=ef9617e7
# Processing participant: id=3d6143f3
# Processing participant: id=d5b089a4
# Processing participant: id=db9eae59
# Processing participant: id=4a475a9f
# Processing participant: id=fecc07d6
# Processing participant: id=3875d4de
# Processing participant: id=012cadd8
# Processing participant: id=dd747bba
# Processing participant: id=36c060b9
# Processing participant: id=2bbcfd43
# Processing participant: id=73ec551e
# Processing participant: id=ed711416
# Processing participant: id=215ca39b
# Processing participant: id=1c063ebc
# Processing participant: id=1e5f6199
# Processing participant: id=d19e1025
# Processing participant: id=73ffa609
# Processing participant: id=d0ac4f1c
# Processing participant: id=350cf38b
# Processing participant: id=6dfe4a75
# Processing participant: id=25a3a723
# Processing participant: id=8a645723
# Processing participant: id=68be3d5c
# Processing participant: id=709457f3
# Processing participant: id=4aa87859
# Processing participant: id=47350ac6
# Processing participant: id=b7a61f8d
# Processing participant: id=4950e24c
# Processing participant: id=bb0d7d92
# Processing participant: id=08660d12
# Processing participant: id=1957153d
# Processing participant: id=da19c97e
# Processing participant: id=c8fbbc8a
# Processing participant: id=ffcd4dbd
# Processing participant: id=9fb96ae3
# Processing participant: id=38cccd6d
# Processing participant: id=19098ef0
# Processing participant: id=cb3b7c3c
# Processing participant: id=11739de2
# Processing participant: id=fdc11b96
# Processing participant: id=6247cc15
# Processing participant: id=1911731d
# Processing participant: id=f8ff0bc8
# Processing participant: id=080698b7
# Processing participant: id=7dc65b92
# Processing participant: id=7b8842c3
# Processing participant: id=fc8e4de4
# Processing participant: id=6d707ac3
# Processing participant: id=ac3ba541
# Processing participant: id=f5ad7abc
# Processing participant: id=ebd6f819
# Processing participant: id=3f1cf5ba
# Processing participant: id=4442c376
# Processing participant: id=3c8f474a
# Processing participant: id=83846d0c
# Processing participant: id=001f3379
# Processing participant: id=948e1435
# Processing participant: id=bd4ccd4c
# Processing participant: id=5ee595e8
# Processing participant: id=b9c085ab
# Processing participant: id=2bac0893
# Processing participant: id=5ddbac80
# Processing participant: id=e4762a2b
# Processing participant: id=2f154763
# Processing participant: id=0983654b
# Processing participant: id=f6d879aa
# Processing participant: id=c5cfaeae
# Processing participant: id=a9b84b96
# Processing participant: id=cd703872
# Processing participant: id=898096eb
# Processing participant: id=14391970
# Processing participant: id=677038b5
# Processing participant: id=ea544af3
# Processing participant: id=ec6b57b4
# Processing participant: id=69b65679
# Processing participant: id=e4d396d7
# Processing participant: id=eb93a46a
# Processing participant: id=9eb283e4
# Processing participant: id=aa1700c7
# Processing participant: id=154d1191
# Processing participant: id=04afb6f9
# Processing participant: id=6197a2ce
# Processing participant: id=b41cee02
# Processing participant: id=24398aed
# Processing participant: id=f3020788
# Processing participant: id=a922ef3f
# Processing participant: id=ce6eeadf
# Processing participant: id=8078b7de
# Processing participant: id=7e46b693
# Processing participant: id=4d61a44e
# Processing participant: id=e0283d3d
# Processing participant: id=c5462e87
# Processing participant: id=f44f1227
# Processing participant: id=5ef3d64e
# Processing participant: id=fdf4691f
# Processing participant: id=83eda373
# Processing participant: id=0f6b71c4
# Processing participant: id=5264bb0e
# Processing participant: id=8e59a69a
# Processing participant: id=0d279d77
# Processing participant: id=db3b1dd1
# Processing participant: id=af485add
# Processing participant: id=7c21ad67
# Processing participant: id=4307d287
# Processing participant: id=7265f1e5
# Processing participant: id=cba39753
# Processing participant: id=75ad73ee
# Processing participant: id=ac1ad4a7
# Processing participant: id=c1373df0
# Processing participant: id=8376acc5
# Processing participant: id=481a1861
# Processing participant: id=e0869709
# Processing participant: id=0eddd8e5
# Processing participant: id=dc33dcef
# Processing participant: id=745e6065
# Processing participant: id=58dfccdb
# Processing participant: id=bf31e0a7
# Processing participant: id=1eda934b
# Processing participant: id=f35b607c
# Processing participant: id=de91310c
# Processing participant: id=063b16fc
# Processing participant: id=a40c8316
# Processing participant: id=03a9019b
# Processing participant: id=58ada72e
# Processing participant: id=9d0670dd
# Processing participant: id=b95aad8d
# Processing participant: id=75b0446f
# Processing participant: id=02cebf33
# Processing participant: id=6b773506
# Processing participant: id=43f44f6c
# Processing participant: id=15dbc929
# Processing participant: id=ab36aa48
# Processing participant: id=a774c63b
# Processing participant: id=63fc9770
# Processing participant: id=ae712150
# Processing participant: id=5c2c136d
# Processing participant: id=a1942b0b
# Processing participant: id=15f217a6
# Processing participant: id=29c54890
# Processing participant: id=7a6d26a2
# Processing participant: id=1fed3943
# Processing participant: id=2a9e0dee
# Processing participant: id=f8bf4a1c
# Processing participant: id=806d877f
# Processing participant: id=e28c0bfa
# Processing participant: id=24ab10c6
# Processing participant: id=1d78b3c3
# Processing participant: id=0745c390
# Processing participant: id=99b15811
# Processing participant: id=bea525dc
# Processing participant: id=08577722
# Processing participant: id=e4614ec6
# Processing participant: id=e1e02e28
# Processing participant: id=c8270746
# Processing participant: id=2496c491
# Processing participant: id=4b0f961e
# Processing participant: id=0d4fa8f4
# Processing participant: id=92622443
# Processing participant: id=d6cca65e
# Processing participant: id=e4e58096
# Processing participant: id=419d05c6
# Processing participant: id=11f9b26c
# Processing participant: id=7bdbf66f
# Processing participant: id=6d5944a9
# Processing participant: id=5f78f7b9
# Processing participant: id=f75c957f
# Processing participant: id=2a3fcf9a
# Processing participant: id=df98fbb4
# Processing participant: id=678598dd
# Processing participant: id=efa35d35
# Processing participant: id=06eb8adb
# Processing participant: id=a614af1b
# Processing participant: id=cd8f3c61
# Processing participant: id=331733c7
# Processing participant: id=416b6ba2
# Processing participant: id=cbcf8cf2
# Processing participant: id=04f094a8
# Processing participant: id=0e3b0bd2
# Processing participant: id=48df987b
# Processing participant: id=a00c85e7
# Processing participant: id=0ec403df
# Processing participant: id=d05f5d71
# Processing participant: id=9e027e04
# Processing participant: id=b9cf3f7c
# Processing participant: id=34ec5de4
# Processing participant: id=659fec57
# Processing participant: id=f6c20447
# Processing participant: id=a6969e1a
# Processing participant: id=7800a084
# Processing participant: id=b802aec3
# Processing participant: id=43629a34
# Processing participant: id=a08ebf6e
# Processing participant: id=22e44415
# Processing participant: id=3950aa00
# Processing participant: id=a4e0447e
# Processing participant: id=836b4de3
# Processing participant: id=d77ac332
# Processing participant: id=764d8b42
# Processing participant: id=3d736110
# Processing participant: id=ca3204b0
# Processing participant: id=108b8659
# Processing participant: id=c73dd2e4
# Processing participant: id=064e8da5
# Processing participant: id=6f49c8d0
# Processing participant: id=c6da0d4b
# Processing participant: id=3d48430d
# Processing participant: id=c8cc2e1b
# Processing participant: id=e8e82627
# Processing participant: id=72c9c38d
# Processing participant: id=51f38b37
# Processing participant: id=79bd36b6
# Processing participant: id=0c4eabac
# Processing participant: id=1606f203
# Processing participant: id=bd8397cb
# Processing participant: id=93fda84a
# Processing participant: id=4d19854c
# Processing participant: id=9e4385f7
# Processing participant: id=9cee3c19
# Processing participant: id=a8d9de72
# Processing participant: id=a5099438
# Processing participant: id=ebf2b0c9
# Processing participant: id=440acf4f
# Processing participant: id=f11e17c0
# Processing participant: id=5e359a08
# Processing participant: id=86a8e0d6
# Processing participant: id=9aa1a2ae
# Processing participant: id=fe9c71d8
# Processing participant: id=92293b06
# Processing participant: id=3fcef947
# Processing participant: id=f869d220
# Processing participant: id=00115b9f
# Processing participant: id=bba6ff20
# Processing participant: id=a3391798
# Processing participant: id=0d570d3e
# Processing participant: id=55f9338e
# Processing participant: id=f1bd0f59
# Processing participant: id=fb04f7dd
# Processing participant: id=52e9e467
# Processing participant: id=d2d9b474
# Processing participant: id=a65b2226
# Processing participant: id=24a3b16d
# Processing participant: id=0cbe4e54
# Processing participant: id=50707f1e
# Processing participant: id=e4ab3b12
# Processing participant: id=7f26f78c
# Processing participant: id=35198c2d
# Processing participant: id=23e71e7c
# Processing participant: id=f584742f
# Processing participant: id=6c0fe935
# Processing participant: id=5ea2c305
# Processing participant: id=14b3d6e5
# Processing participant: id=76781cd8
# Processing participant: id=d661ddf7
# Processing participant: id=3acb5be3
# Processing participant: id=4177e5e5
# Processing participant: id=8f2d131f
# Processing participant: id=14a6e58e
# Processing participant: id=8823b020
# Processing participant: id=4280076d
# Processing participant: id=05db1b9b
# Processing participant: id=a4f13c0d
# Processing participant: id=4b3c7594
# Processing participant: id=93c93585
# Processing participant: id=2cd9b5a3
# Processing participant: id=bbe5bedd
# Processing participant: id=9e052412
# Processing participant: id=3216b978
# Processing participant: id=b074f33b
# Processing participant: id=579e50bd
# Processing participant: id=9540fa8e
# Processing participant: id=2cda86bd
# Processing participant: id=f47abc42
# Processing participant: id=c2b40d6f
# Processing participant: id=6c737069
# Processing participant: id=c9902f48
# Processing participant: id=47240aa3
# Processing participant: id=5f9dddb4
# Processing participant: id=6774ba64
# Processing participant: id=325afd3d
# Processing participant: id=84875079
# Processing participant: id=1f2164a4
# Processing participant: id=c73f149c
# Processing participant: id=53905a2c
# Processing participant: id=1eedf45e
# Processing participant: id=3ba48ca7
# Processing participant: id=c38a5c9b
# Processing participant: id=7c194077
# Processing participant: id=c09d41cd
# Processing participant: id=f1049268
# Processing participant: id=aaefeff0
# Processing participant: id=63d4ab9a
# Processing participant: id=432aff11
# Processing participant: id=40087bc5
# Processing participant: id=067b9287
# Processing participant: id=abaf745c
# Processing participant: id=f6c0e2b7
# Processing participant: id=055156e2
# Processing participant: id=9052579b
# Processing participant: id=119e181e
# Processing participant: id=4a17b463
# Processing participant: id=3c0aba64
# Processing participant: id=9f70688f
# Processing participant: id=23567787
# Processing participant: id=380029ef
# Processing participant: id=f6d6f400
# Processing participant: id=613fc399
# Processing participant: id=ee21612e
# Processing participant: id=9ddfb9e6
# Processing participant: id=cadd4ae5
# Processing participant: id=abac67cc
# Processing participant: id=db38d1f9
# Processing participant: id=97bb0cc0
# Processing participant: id=d445fb74
# Processing participant: id=4e85505f
# Processing participant: id=f81598bf
# Processing participant: id=21a76448
# Processing participant: id=6a16089d
# Processing participant: id=1b32427b
# Processing participant: id=cd39e576
# Processing participant: id=1e08b1dc
# Processing participant: id=2fba6cf4
# Processing participant: id=5d885b20
# Processing participant: id=0c98f822
# Processing participant: id=bc6bd8b2
# Processing participant: id=101c27f1
# Processing participant: id=ef07f833
# Processing participant: id=3983d3cd
# Processing participant: id=9570bfb7
# Processing participant: id=c6ead822
# Processing participant: id=43720c15
# Processing participant: id=22f43a12
# Processing participant: id=26aeacdf
# Processing participant: id=f0957ca1
# Processing participant: id=5b9ff85e
# Processing participant: id=07048067
# Processing participant: id=c446e1c5
# Processing participant: id=02cf7384
# Processing participant: id=ec9195be
# Processing participant: id=39fb1ad0
# Processing participant: id=f57de847
# Processing participant: id=32dcc8ab
# Processing participant: id=a5974a7d
# Processing participant: id=a808ad0a
# Processing participant: id=913bea9f
# Processing participant: id=c96b9609
# Processing participant: id=685cc0f1
# Processing participant: id=65fe69c0
# Processing participant: id=aae9800e
# Processing participant: id=f32a9580
# Processing participant: id=994ee014
# Processing participant: id=855c6099
# Processing participant: id=5b66b6f2
# Processing participant: id=f0d76b32
# Processing participant: id=b37281d5
# Processing participant: id=83711ef5
# Processing participant: id=26d541c2
# Processing participant: id=6699c999
# Processing participant: id=6e128c6b
# Processing participant: id=c6d4b453
# Processing participant: id=8e749c85
# Processing participant: id=a49eda7f
# Processing participant: id=2cb0db2c
# Processing participant: id=119d7562
# Processing participant: id=13fca10c
# Processing participant: id=f5b2acf0
# Processing participant: id=eaab7a96
# Processing participant: id=10ad8c48
# Processing participant: id=31648caa
# Processing participant: id=b08f0ca4
# Processing participant: id=e892aec6
# Processing participant: id=7d8f1716
# Processing participant: id=0720320e
# Processing participant: id=2afea280
# Processing participant: id=7ce36c38
# Processing participant: id=ad380962
# Processing participant: id=113f5798
# Processing participant: id=b9e90f7f
# Processing participant: id=a302a015
# Processing participant: id=2a6a6b92
# Processing participant: id=7c39c8e5
# Processing participant: id=8abbbc38
# Processing participant: id=72a0c969
# Processing participant: id=57f6fa6c
# Processing participant: id=e072b994
# Processing participant: id=c7d9e964
# Processing participant: id=a95b4487
# Processing participant: id=e63000c5
# Processing participant: id=b823508b
# Processing participant: id=ea7277b4
# Processing participant: id=9061cc9c
# Processing participant: id=60c1ff37
# Processing participant: id=9105b812
# Processing participant: id=260f542b
# Processing participant: id=3ca35642
# Processing participant: id=bfb421f9
# Processing participant: id=75b53bd4
# Processing participant: id=95cc96cc
# Processing participant: id=6795027a
# Processing participant: id=5f7537cf
# Processing participant: id=338146bd
# Processing participant: id=2da6bf6e
# Processing participant: id=1f7bd44c
# Processing participant: id=ea7adcd6
# Processing participant: id=4940a214
# Processing participant: id=86bd716a
# Processing participant: id=95d57ff9
# Processing participant: id=85d99199
# Processing participant: id=857baaa6
# Processing participant: id=ab54c39e
# Processing participant: id=27d7e5e4
# Processing participant: id=a814e825
# Processing participant: id=8ec2cc63
# Processing participant: id=8148c785
# Processing participant: id=9ce139d3
# Processing participant: id=bbd71a7c
# Processing participant: id=c3adae87
# Processing participant: id=fdea7d9e
# Processing participant: id=0b4014f0
# Processing participant: id=2ac0bd9f
# Processing participant: id=56d9dead
# Processing participant: id=d6776176
# Processing participant: id=ce379a6a
# Processing participant: id=6a864b11
# Processing participant: id=f8674e15
# Processing participant: id=fa3e1e21
# Processing participant: id=812f6873
# Processing participant: id=c3a3f61e
# Processing participant: id=3d36fe8b
# Processing participant: id=ab2ad965
# Processing participant: id=c9879365
# Processing participant: id=f6cc80a9
# Processing participant: id=fb3c2c87
# Processing participant: id=80b46ffb
# Processing participant: id=53814642
# Processing participant: id=71852781
# Processing participant: id=2fef897e
# Processing participant: id=563ebc00
# Processing participant: id=6187d0dc
# Processing participant: id=37bcfa7e
# Processing participant: id=35d2aa41
# Processing participant: id=de742c5c
# Processing participant: id=33d60f7d
# Processing participant: id=436dd613
# Processing participant: id=3e5ee48c
# Processing participant: id=cf1b9d44
# Processing participant: id=34362a9a
# Processing participant: id=db23fbe4
# Processing participant: id=860f4f9c
# Processing participant: id=8875387b
# Processing participant: id=137baaec
# Processing participant: id=2f8ec752
# Processing participant: id=62cd5c74
# Processing participant: id=5f37ceb1
# Processing participant: id=f4114031
# Processing participant: id=8f015125
# Processing participant: id=e88aa867
# Processing participant: id=bc4eaf77
# Processing participant: id=384c3f27
# Processing participant: id=6ac5763a
# Processing participant: id=2c406043
# Processing participant: id=70de1c63
# Processing participant: id=c38585c5
# Processing participant: id=e23a8a0a
# Processing participant: id=38d53b92
# Processing participant: id=e5349ce2
# Processing participant: id=5124169c
# Processing participant: id=d74e4d7c
# Processing participant: id=c45068a1
# Processing participant: id=c6cc7467
# Processing participant: id=a8c1aab5
# Processing participant: id=ecd25dd1
# Processing participant: id=4b71830a
# Processing participant: id=1fc07a80
# Processing participant: id=0b7d9da6
# Processing participant: id=e1ea8dd7
# Processing participant: id=f62b317d
# Processing participant: id=a221c60c
# Processing participant: id=4cabd7aa
# Processing participant: id=2a88cbe9
# Processing participant: id=f4d2f5af
# Processing participant: id=9130a22e
# Processing participant: id=b08423c5
# Processing participant: id=b452f767
# Processing participant: id=c0442863
# Processing participant: id=9c1ea003
# Processing participant: id=c0a7d046
# Processing participant: id=a28c7891
# Processing participant: id=e4b47411
# Processing participant: id=1649ce22
# Processing participant: id=082df556
# Processing participant: id=be210bc7
# Processing participant: id=51364c23
# Processing participant: id=64ed48c4
# Processing participant: id=621066ff
# Processing participant: id=0ed2a3c8
# Processing participant: id=f2d4efd8
# Processing participant: id=b712b69b
# Processing participant: id=89739b1a
# Processing participant: id=4a62661a
# Processing participant: id=04d06a9c
# Processing participant: id=da09ed4b
# Processing participant: id=2f1af08a
# Processing participant: id=f6b719ee
# Processing participant: id=28e973b1
# Processing participant: id=6fb28c2a
# Processing participant: id=d57f6c9e
# Processing participant: id=05bbed1b
# Processing participant: id=7fa51811
# Processing participant: id=dcfcd574
# Processing participant: id=a6fbb2e7
# Processing participant: id=54391716
# Processing participant: id=1a803bfe
# Processing participant: id=3b1b9538
# Processing participant: id=c4c2076b
# Processing participant: id=2f16cad4
# Processing participant: id=b2987a65
# Processing participant: id=2a922ca4
# Processing participant: id=5f1b07e1
# Processing participant: id=2c54d6c5
# Processing participant: id=ef58dd3c
# Processing participant: id=d4d9f7f9
# Processing participant: id=a1ab89aa
# Processing participant: id=f285b43c
# Processing participant: id=e3f71f7a
# Processing participant: id=d791703f
# Processing participant: id=1470a1df
# Processing participant: id=1301f65d
# Processing participant: id=012e3869
# Processing participant: id=5cd83147
# Processing participant: id=9f3ca269
# Processing participant: id=c308b134
# Processing participant: id=5af79adb
# Processing participant: id=9a5aed6c
# Processing participant: id=c00c663c
# Processing participant: id=fe3cbf02
# Processing participant: id=863e40c7
# Processing participant: id=5985f299
# Processing participant: id=adba23f0
# Processing participant: id=2c3b09db
# Processing participant: id=e8b64419
# Processing participant: id=2ee0a1e8
# Processing participant: id=c274a243
# Processing participant: id=233b9425
# Processing participant: id=15227eef
# Processing participant: id=fad07fce
# Processing participant: id=e37d000b
# Processing participant: id=4dfb4e1d
# Processing participant: id=54fef303
# Processing participant: id=e0655da2
# Processing participant: id=f09e7b33
# Processing participant: id=93559639
# Processing participant: id=8f753551
# Processing participant: id=04bb1a76
# Processing participant: id=e7401605
# Processing participant: id=9a7e4c38
# Processing participant: id=2b34dcf3
# Processing participant: id=d28f0d44
# Processing participant: id=2c2dc20d
# Processing participant: id=464a75fb
# Processing participant: id=8e80deb7
# Processing participant: id=6e85a624
# Processing participant: id=6282e693
# Processing participant: id=5c22f241
# Processing participant: id=bdcc7d10
# Processing participant: id=7187caec
# Processing participant: id=a148b46f
# Processing participant: id=7015528d
# Processing participant: id=9ddb06db
# Processing participant: id=ee67eb55
# Processing participant: id=6fcdcb2a
# Processing participant: id=ad0bbf35
# Processing participant: id=edb9d0f3
# Processing participant: id=4926b18a
# Processing participant: id=427037b2
# Processing participant: id=fc49ba65
# Processing participant: id=0b7d7aec
# Processing participant: id=e754411f
# Processing participant: id=b23b9220
# Processing participant: id=81feecad
# Processing participant: id=a7b9546a
# Processing participant: id=0668373f
# Processing participant: id=b69bf1f7
# Processing participant: id=49e4eade
# Processing participant: id=9dc74359
# Processing participant: id=8a6b6912
# Processing participant: id=949f94e5
# Processing participant: id=3268c574
# Processing participant: id=732b2327
# Processing participant: id=0d4800c8
# Processing participant: id=d859115e
# Processing participant: id=e1958a83
# Processing participant: id=b308c03e
# Processing participant: id=f74eda33
# Processing participant: id=db746de0
# Processing participant: id=4859a9f9
# Processing participant: id=31f01671
# Processing participant: id=372a7950
# Processing participant: id=ffed1dd5
# Processing participant: id=526f719b
# Processing participant: id=da5a8921
# Processing participant: id=c3061b23
# Processing participant: id=8a44ea3a
# Processing participant: id=dacc2f83
# Processing participant: id=71850348
# Processing participant: id=9402b885
# Processing participant: id=3065aa2f
# Processing participant: id=7a0136e0
# Processing participant: id=d9c82502
# Processing participant: id=218faf6f
# Processing participant: id=0c4e2d68
# Processing participant: id=50b2b84b
# Processing participant: id=25eba023
# Processing participant: id=c0f2a046
# Processing participant: id=f64ae747
# Processing participant: id=7860b64c
# Processing participant: id=d87e2d01
# Processing participant: id=0417c91e
# Processing participant: id=a8926a86
# Processing participant: id=12380b06
# Processing participant: id=f015a18c
# Processing participant: id=68fa4631
# Processing participant: id=06c8b2fb
# Processing participant: id=36530d36
# Processing participant: id=e0ad6550
# Processing participant: id=a5078c62
# Processing participant: id=9271574b
# Processing participant: id=1b6fb363
# Processing participant: id=2c483245
# Processing participant: id=df556fd2
# Processing participant: id=fb9c5a33
# Processing participant: id=f93010a8
# Processing participant: id=e1a4575f
# Processing participant: id=e76ad778
# Processing participant: id=82ec9747
# Processing participant: id=22375702
# Processing participant: id=85d9c915
# Processing participant: id=ab987c75
# Processing participant: id=3d970ce4
# Processing participant: id=ac66c144
# Processing participant: id=36c1f189
# Processing participant: id=9027c805
# Processing participant: id=11be5d2e
# Processing participant: id=ff18b749
# Processing participant: id=5d762840
# Processing participant: id=52ce9b8b
# Processing participant: id=21eb6d47
# Processing participant: id=14568d61
# Processing participant: id=adaf7461
# Processing participant: id=b9b22bff
# Processing participant: id=4fd7e043
# Processing participant: id=b120a337
# Processing participant: id=7fa7ccc4
# Processing participant: id=ec8f8f95
# Processing participant: id=23dafdab
# Processing participant: id=48e69212
# Processing participant: id=6a2fd807
# Processing participant: id=3d3b87db
# Processing participant: id=1f5835cd
# Processing participant: id=32b8490d
# Processing participant: id=3a594acf
# Processing participant: id=3c620257
# Processing participant: id=6ac5eaaf
# Processing participant: id=8d8b8553
# Processing participant: id=0b518637
# Processing participant: id=9b328d6c
# Processing participant: id=9a2082cf
# Processing participant: id=4f059221
# Processing participant: id=4ca242ea
# Processing participant: id=81a4b826
# Processing participant: id=897da2c8
# Processing participant: id=40aae75f
# Processing participant: id=86335468
# Processing participant: id=5a313293
# Processing participant: id=b1f064ac
# Processing participant: id=a3b146ca
# Processing participant: id=8ba98f12
# Processing participant: id=17c1ae23
# Processing participant: id=93c72a97
# Processing participant: id=96de5f57
# Processing participant: id=3e398bf9
# Processing participant: id=467c549f
# Processing participant: id=3ab539f0
# Processing participant: id=25849c6c
# Processing participant: id=7347b54e
# Processing participant: id=ad536dea
# Processing participant: id=de3750cc
# Processing participant: id=dd689eb0
# Processing participant: id=144a9a79
# Processing participant: id=aecc7e74
# Processing participant: id=f67908e7
# Processing participant: id=fc41be2f
# Processing participant: id=29b37b4a
# Processing participant: id=5c186496
# Processing participant: id=101774f0
# Processing participant: id=49a1931d
# Processing participant: id=a3858c6a
# Processing participant: id=327ef356
# Processing participant: id=4a6af685
# Processing participant: id=4cde1e34
# Processing participant: id=0d924604
# Processing participant: id=e315fdd7
# Processing participant: id=cd89d5f1
# Processing participant: id=df4ab9b1
# Processing participant: id=6ebfdc95
# Processing participant: id=c6575d38
# Processing participant: id=0b50f3fa
# Processing participant: id=278e8a51
# Processing participant: id=cb73fed9
# Processing participant: id=89a26502
# Processing participant: id=56ef356c
# Processing participant: id=71ee31f8
# Processing participant: id=31b74cd4
# Processing participant: id=6abd21d4
# Processing participant: id=6595d479
# Processing participant: id=fdb6b48b
# Processing participant: id=35daea65
# Processing participant: id=e243119c
# Processing participant: id=bb808a71
# Processing participant: id=78704d22
# Processing participant: id=6c6cd633
# Processing participant: id=9ff73d95
# Processing participant: id=ea4619ec
# Processing participant: id=3b091b83
# Processing participant: id=e40319d7
# Processing participant: id=4f20b188
# Processing participant: id=5d3b6ea5
# Processing participant: id=d08806a2
# Processing participant: id=9fa68512
# Processing participant: id=fd56e059
# Processing participant: id=9cf04c41
# Processing participant: id=a297d1b9
# Processing participant: id=c2e15338
# Processing participant: id=658e66ec
# Processing participant: id=4e6c7a75
# Processing participant: id=059eed01
# Processing participant: id=09b29113
# Processing participant: id=8ddb6b8d
# Processing participant: id=22536a61
# Processing participant: id=37ae1239
# Processing participant: id=93c06d4c
# Processing participant: id=93fd93c4
# Processing participant: id=fd0d9bca
# Processing participant: id=9cba0d0e
# Processing participant: id=30d2fd47
# Processing participant: id=a26c3e8f
# Processing participant: id=8a9e653f
# Processing participant: id=de3ecca9
# Processing participant: id=10e46254
# Processing participant: id=954a4c2e
# Processing participant: id=9e964060
# Processing participant: id=428c37ea
# Processing participant: id=537dc410
# Processing participant: id=04cb2c30
# Processing participant: id=c9dabad5
# Processing participant: id=4dc4ed56
# Processing participant: id=2d0bbbd3
# Processing participant: id=d5fde276
# Processing participant: id=099e3614
# Processing participant: id=321202d4
# Processing participant: id=ec13a1b9
# Processing participant: id=a4481101
# Processing participant: id=fab75c2c
# Processing participant: id=75c13e08
# Processing participant: id=b2b56219
# Processing participant: id=83912085
# Processing participant: id=0fbb3ca5
# Processing participant: id=9ab4909f
# Processing participant: id=cd144127
# Processing participant: id=1b2eea8f
# Processing participant: id=8c0ca955
# Processing participant: id=ba73bc7c
# Processing participant: id=d5a8d9b0
# Processing participant: id=31d61741
# Processing participant: id=5f099188
# Processing participant: id=f7fc97cf
# Processing participant: id=e7d08824
# Processing participant: id=cd1fff5a
# Processing participant: id=b94ec4a1
# Processing participant: id=83379672
# Processing participant: id=b25abc27
# Processing participant: id=a9c53cdb
# Processing participant: id=9bdd6964
# Processing participant: id=a2994e55
# Processing participant: id=350dbeba
# Processing participant: id=57c4f2b4
# Processing participant: id=029a19c9
# Processing participant: id=1c23295e
# Processing participant: id=a5dbb00a
# Processing participant: id=4a1440d9
# Processing participant: id=c55187b4
# Processing participant: id=84b7d89d
# Processing participant: id=9b96b0e4
# Processing participant: id=a8b0428d
# Processing participant: id=f420b05a
# Processing participant: id=214f46e8
# Processing participant: id=daf3969c
# Processing participant: id=cfe4cf40
# Processing participant: id=c731458f
# Processing participant: id=adc2d620
# Processing participant: id=22b4191a
# Processing participant: id=05e94f88
# Processing participant: id=43a7386d
# Processing participant: id=2840643b
# Processing participant: id=1b329556
# Processing participant: id=62b873a2
# Processing participant: id=57de6095
# Interval Statistics Across Participants:
#         mean_interval  median_interval  25th_percentile  75th_percentile  \
# count     996.000000            996.0            996.0            996.0
# mean       47.806981              5.0              5.0              5.0
# std       367.242401              0.0              0.0              0.0
# min         5.000000              5.0              5.0              5.0
# 25%         5.000000              5.0              5.0              5.0
# 50%         5.000000              5.0              5.0              5.0
# 75%         9.798941              5.0              5.0              5.0
# max      7105.172786              5.0              5.0              5.0
#
#        90th_percentile  max_interval
# count       996.000000  9.960000e+02
# mean          5.015060  1.018879e+05
# std           0.475293  3.233020e+05
# min           5.000000  5.000000e+00
# 25%           5.000000  5.000000e+00
# 50%           5.000000  5.000000e+00
# 75%           5.000000  7.428125e+04
# max          20.000000  6.584150e+06
