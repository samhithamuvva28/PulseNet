# %%
import os
import pandas as pd
import numpy as np

# Function to extract features from Actigraphy data
def extract_features(data):
    # Statistical features
    mean_x = data['X'].mean()
    mean_y = data['Y'].mean()
    mean_z = data['Z'].mean()
    std_x = data['X'].std()
    std_y = data['Y'].std()
    std_z = data['Z'].std()
    
    mean_enmo = data['enmo'].mean()
    std_enmo = data['enmo'].std()
    max_enmo = data['enmo'].max()
    min_enmo = data['enmo'].min()

    # Activity magnitude
    magnitude = np.sqrt(data['X']**2 + data['Y']**2 + data['Z']**2)
    mean_magnitude = magnitude.mean()
    std_magnitude = magnitude.std()
    
    # Activity level (binned)
    activity_level = pd.cut(
        magnitude,
        bins=[0, 0.5, 1.0, 1.5, 2.0],
        labels=['Very Low', 'Low', 'Medium', 'High'],
        include_lowest=True
    ).mode()[0]  # Most common activity level

    # Inactivity percentage
    inactivity_percentage = (data['enmo'] == 0).mean() * 100

    # Non-wear percentage
    non_wear_percentage = (data['non-wear_flag'] == 1).mean() * 100

    # Created a dictionary with the extracted features
    features = {
        'mean_x': mean_x,
        'mean_y': mean_y,
        'mean_z': mean_z,
        'std_x': std_x,
        'std_y': std_y,
        'std_z': std_z,
        'mean_enmo': mean_enmo,
        'std_enmo': std_enmo,
        'max_enmo': max_enmo,
        'min_enmo': min_enmo,
        'mean_magnitude': mean_magnitude,
        'std_magnitude': std_magnitude,
        'activity_level': activity_level,
        'inactivity_percentage': inactivity_percentage,
        'non_wear_percentage': non_wear_percentage
    }
    
    # Returned the features as a DataFrame
    return pd.DataFrame([features])

# Directory containing the parquet files
input_directory = "C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/cleaned_series_train.parquet"
output_directory = "C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/extracted_features"

# Checked if output directory exists, if not, create it
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Listed all parquet files in the directory
parquet_files = [f for f in os.listdir(input_directory) if f.endswith('.parquet')]

# Initialized an empty list to collect all extracted features
all_features = []

# Processed each parquet file
for file in parquet_files:
    file_path = os.path.join(input_directory, file)
    try:
        # Read the parquet file
        data = pd.read_parquet(file_path)
        
        # Removed the 'light' column if it exists
        if 'light' in data.columns:
            data = data.drop(columns=['light'])

        # Extracted features for the current participant
        participant_features = extract_features(data)
        
        # Added the participant features to the list
        all_features.append(participant_features)
        
        print(f"Processed file: {file}")
    except Exception as e:
        print(f"Error processing file {file}: {e}")

# Concatenated all the features into a single DataFrame
final_features = pd.concat(all_features, ignore_index=True)

# Dynamically created the output file path
output_file = os.path.join(output_directory, "extracted_features_all_participants.parquet")

# Saved the final extracted features to a parquet file
final_features.to_parquet(output_file)
#success message and a preview of the features
print(f"Features extracted and saved successfully for all participants.")
print(final_features.head())  # Print the first few rows for review
# Out:
# Processed file: id=00115b9f.parquet
# Processed file: id=001f3379.parquet
# Processed file: id=00f332d1.parquet
# Processed file: id=01085eb3.parquet
# Processed file: id=012cadd8.parquet
# Processed file: id=012e3869.parquet
# Processed file: id=029a19c9.parquet
# Processed file: id=02cebf33.parquet
# Processed file: id=02cf7384.parquet
# Processed file: id=035c96dd.parquet
# Processed file: id=03a9019b.parquet
# Processed file: id=0417c91e.parquet
# Processed file: id=045a0a94.parquet
# Processed file: id=04afb6f9.parquet
# Processed file: id=04bb1a76.parquet
# Processed file: id=04cb2c30.parquet
# Processed file: id=04d06a9c.parquet
# Processed file: id=04f094a8.parquet
# Processed file: id=051680a0.parquet
# Processed file: id=055156e2.parquet
# Processed file: id=059eed01.parquet
# Processed file: id=05bbed1b.parquet
# Processed file: id=05db1b9b.parquet
# Processed file: id=05e94f88.parquet
# Processed file: id=063b16fc.parquet
# Processed file: id=064e8da5.parquet
# Processed file: id=0668373f.parquet
# Processed file: id=067b9287.parquet
# Processed file: id=06c8b2fb.parquet
# Processed file: id=06eb8adb.parquet
# Processed file: id=070386b2.parquet
# Processed file: id=07048067.parquet
# Processed file: id=0720320e.parquet
# Processed file: id=0745c390.parquet
# Processed file: id=080698b7.parquet
# Processed file: id=082df556.parquet
# Processed file: id=08577722.parquet
# Processed file: id=08660d12.parquet
# Processed file: id=089a6b19.parquet
# Processed file: id=09331bb8.parquet
# Processed file: id=0983654b.parquet
# Processed file: id=099e3614.parquet
# Processed file: id=09b29113.parquet
# Processed file: id=0a418b57.parquet
# Processed file: id=0a431608.parquet
# Processed file: id=0b4014f0.parquet
# Processed file: id=0b50f3fa.parquet
# Processed file: id=0b518637.parquet
# Processed file: id=0b7d7aec.parquet
# Processed file: id=0b7d9da6.parquet
# Processed file: id=0bd89878.parquet
# Processed file: id=0bfe4fc9.parquet
# Processed file: id=0c4e2d68.parquet
# Processed file: id=0c4eabac.parquet
# Processed file: id=0c98f822.parquet
# Processed file: id=0cbe4e54.parquet
# Processed file: id=0d01bbf2.parquet
# Processed file: id=0d279d77.parquet
# Processed file: id=0d4800c8.parquet
# Processed file: id=0d4fa8f4.parquet
# Processed file: id=0d570d3e.parquet
# Processed file: id=0d924604.parquet
# Processed file: id=0e3b0bd2.parquet
# Processed file: id=0ec403df.parquet
# Processed file: id=0ed2a3c8.parquet
# Processed file: id=0eddd8e5.parquet
# Processed file: id=0f6b71c4.parquet
# Processed file: id=0fbb3ca5.parquet
# Processed file: id=101774f0.parquet
# Processed file: id=101c27f1.parquet
# Processed file: id=108b8659.parquet
# Processed file: id=10ad8c48.parquet
# Processed file: id=10e46254.parquet
# Processed file: id=113f5798.parquet
# Processed file: id=11739de2.parquet
# Processed file: id=119d7562.parquet
# Processed file: id=119e181e.parquet
# Processed file: id=11be5d2e.parquet
# Processed file: id=11f9b26c.parquet
# Processed file: id=12380b06.parquet
# Processed file: id=12a607f6.parquet
# Processed file: id=1301f65d.parquet
# Processed file: id=1314bc8c.parquet
# Processed file: id=137baaec.parquet
# Processed file: id=13eee030.parquet
# Processed file: id=13fca10c.parquet
# Processed file: id=14391970.parquet
# Processed file: id=144a9a79.parquet
# Processed file: id=14568d61.parquet
# Processed file: id=1470a1df.parquet
# Processed file: id=14a6e58e.parquet
# Processed file: id=14b3d6e5.parquet
# Processed file: id=15227eef.parquet
# Processed file: id=154d1191.parquet
# Processed file: id=15dbc929.parquet
# Processed file: id=15f217a6.parquet
# Processed file: id=15f2e240.parquet
# Processed file: id=1606f203.parquet
# Processed file: id=1649ce22.parquet
# Processed file: id=17c1ae23.parquet
# Processed file: id=1837456f.parquet
# Processed file: id=18b8b2f6.parquet
# Processed file: id=19098ef0.parquet
# Processed file: id=1911731d.parquet
# Processed file: id=19455336.parquet
# Processed file: id=1957153d.parquet
# Processed file: id=1a803bfe.parquet
# Processed file: id=1aae1de3.parquet
# Processed file: id=1aff6762.parquet
# Processed file: id=1b2eea8f.parquet
# Processed file: id=1b32427b.parquet
# Processed file: id=1b329556.parquet
# Processed file: id=1b5b34bc.parquet
# Processed file: id=1b6fb363.parquet
# Processed file: id=1c063ebc.parquet
# Processed file: id=1c23295e.parquet
# Processed file: id=1c5ba087.parquet
# Processed file: id=1cd37b36.parquet
# Processed file: id=1d78b3c3.parquet
# Processed file: id=1e08b1dc.parquet
# Processed file: id=1e5f6199.parquet
# Processed file: id=1e87baed.parquet
# Processed file: id=1eda934b.parquet
# Processed file: id=1eea8df2.parquet
# Processed file: id=1eedf45e.parquet
# Processed file: id=1f2164a4.parquet
# Processed file: id=1f5835cd.parquet
# Processed file: id=1f65fa82.parquet
# Processed file: id=1f7bd44c.parquet
# Processed file: id=1fc07a80.parquet
# Processed file: id=1fed3943.parquet
# Processed file: id=214f46e8.parquet
# Processed file: id=215ca39b.parquet
# Processed file: id=218faf6f.parquet
# Processed file: id=21a76448.parquet
# Processed file: id=21eb6d47.parquet
# Processed file: id=221e37e0.parquet
# Processed file: id=22375702.parquet
# Processed file: id=224fc39a.parquet
# Processed file: id=22536a61.parquet
# Processed file: id=22b4191a.parquet
# Processed file: id=22c72c4e.parquet
# Processed file: id=22e44415.parquet
# Processed file: id=22f43a12.parquet
# Processed file: id=233b9425.parquet
# Processed file: id=23567787.parquet
# Processed file: id=23dafdab.parquet
# Processed file: id=23e024bd.parquet
# Processed file: id=23e71e7c.parquet
# Processed file: id=24398aed.parquet
# Processed file: id=2496c491.parquet
# Processed file: id=24a3b16d.parquet
# Processed file: id=24ab10c6.parquet
# Processed file: id=25849c6c.parquet
# Processed file: id=25a3a723.parquet
# Processed file: id=25eba023.parquet
# Processed file: id=260f542b.parquet
# Processed file: id=26190ddd.parquet
# Processed file: id=26aeacdf.parquet
# Processed file: id=26d541c2.parquet
# Processed file: id=2760be91.parquet
# Processed file: id=278e8a51.parquet
# Processed file: id=27d7e5e4.parquet
# Processed file: id=2812951b.parquet
# Processed file: id=2840643b.parquet
# Processed file: id=2898269f.parquet
# Processed file: id=28e973b1.parquet
# Processed file: id=29587a31.parquet
# Processed file: id=29b37b4a.parquet
# Processed file: id=29c54890.parquet
# Processed file: id=2a0b8386.parquet
# Processed file: id=2a3fcf9a.parquet
# Processed file: id=2a6a6b92.parquet
# Processed file: id=2a88cbe9.parquet
# Processed file: id=2a922ca4.parquet
# Processed file: id=2a9e0dee.parquet
# Processed file: id=2ac0bd9f.parquet
# Processed file: id=2afea280.parquet
# Processed file: id=2b34dcf3.parquet
# Processed file: id=2bac0893.parquet
# Processed file: id=2bbcfd43.parquet
# Processed file: id=2c2dc20d.parquet
# Processed file: id=2c3b09db.parquet
# Processed file: id=2c406043.parquet
# Processed file: id=2c483245.parquet
# Processed file: id=2c54d6c5.parquet
# Processed file: id=2ca2206f.parquet
# Processed file: id=2cb0db2c.parquet
# Processed file: id=2cd9b5a3.parquet
# Processed file: id=2cda86bd.parquet
# Processed file: id=2d0bbbd3.parquet
# Processed file: id=2da6bf6e.parquet
# Processed file: id=2e17c497.parquet
# Processed file: id=2e5f5207.parquet
# Processed file: id=2ee0a1e8.parquet
# Processed file: id=2f154763.parquet
# Processed file: id=2f16cad4.parquet
# Processed file: id=2f1af08a.parquet
# Processed file: id=2f8ec752.parquet
# Processed file: id=2fba6cf4.parquet
# Processed file: id=2fef897e.parquet
# Processed file: id=3065aa2f.parquet
# Processed file: id=30d2fd47.parquet
# Processed file: id=31648caa.parquet
# Processed file: id=31b74cd4.parquet
# Processed file: id=31d61741.parquet
# Processed file: id=31f01671.parquet
# Processed file: id=321202d4.parquet
# Processed file: id=3216b978.parquet
# Processed file: id=325afd3d.parquet
# Processed file: id=3268c574.parquet
# Processed file: id=327ef356.parquet
# Processed file: id=32b8490d.parquet
# Processed file: id=32dcc8ab.parquet
# Processed file: id=331733c7.parquet
# Processed file: id=338146bd.parquet
# Processed file: id=33d60f7d.parquet
# Processed file: id=33fe1b04.parquet
# Processed file: id=34362a9a.parquet
# Processed file: id=34ec5de4.parquet
# Processed file: id=350cf38b.parquet
# Processed file: id=350dbeba.parquet
# Processed file: id=35198c2d.parquet
# Processed file: id=351cd4ec.parquet
# Processed file: id=35d2aa41.parquet
# Processed file: id=35daea65.parquet
# Processed file: id=35fa2ebf.parquet
# Processed file: id=36530d36.parquet
# Processed file: id=36c060b9.parquet
# Processed file: id=36c1f189.parquet
# Processed file: id=372a7950.parquet
# Processed file: id=37995242.parquet
# Processed file: id=37ae1239.parquet
# Processed file: id=37bcfa7e.parquet
# Processed file: id=380029ef.parquet
# Processed file: id=3826be66.parquet
# Processed file: id=384c3f27.parquet
# Processed file: id=3875d4de.parquet
# Processed file: id=38cccd6d.parquet
# Processed file: id=38d53b92.parquet
# Processed file: id=3950aa00.parquet
# Processed file: id=397efe7a.parquet
# Processed file: id=3983d3cd.parquet
# Processed file: id=39fb1ad0.parquet
# Processed file: id=3a594acf.parquet
# Processed file: id=3ab539f0.parquet
# Processed file: id=3acb5be3.parquet
# Processed file: id=3b091b83.parquet
# Processed file: id=3b1b9538.parquet
# Processed file: id=3ba48ca7.parquet
# Processed file: id=3c0aba64.parquet
# Processed file: id=3c2cf08e.parquet
# Processed file: id=3c620257.parquet
# Processed file: id=3c8f474a.parquet
# Processed file: id=3ca35642.parquet
# Processed file: id=3d36fe8b.parquet
# Processed file: id=3d3b87db.parquet
# Processed file: id=3d3dd3ae.parquet
# Processed file: id=3d48430d.parquet
# Processed file: id=3d6143f3.parquet
# Processed file: id=3d736110.parquet
# Processed file: id=3d970ce4.parquet
# Processed file: id=3e398bf9.parquet
# Processed file: id=3e5d5b58.parquet
# Processed file: id=3e5ee48c.parquet
# Processed file: id=3f1cf5ba.parquet
# Processed file: id=3f1f23e7.parquet
# Processed file: id=3fcef947.parquet
# Processed file: id=40087bc5.parquet
# Processed file: id=408bed19.parquet
# Processed file: id=40aae75f.parquet
# Processed file: id=416b6ba2.parquet
# Processed file: id=4177e5e5.parquet
# Processed file: id=419d05c6.parquet
# Processed file: id=427037b2.parquet
# Processed file: id=4280076d.parquet
# Processed file: id=428970d4.parquet
# Processed file: id=428c37ea.parquet
# Processed file: id=429cc266.parquet
# Processed file: id=4307d287.parquet
# Processed file: id=432aff11.parquet
# Processed file: id=43629a34.parquet
# Processed file: id=436dd613.parquet
# Processed file: id=43720c15.parquet
# Processed file: id=43a7386d.parquet
# Processed file: id=43f44f6c.parquet
# Processed file: id=43f5d3c5.parquet
# Processed file: id=440acf4f.parquet
# Processed file: id=4442c376.parquet
# Processed file: id=4570c8b8.parquet
# Processed file: id=464a75fb.parquet
# Processed file: id=467c549f.parquet
# Processed file: id=47240aa3.parquet
# Processed file: id=47350ac6.parquet
# Processed file: id=481a1861.parquet
# Processed file: id=4859a9f9.parquet
# Processed file: id=48db8ecf.parquet
# Processed file: id=48df987b.parquet
# Processed file: id=48e69212.parquet
# Processed file: id=4926b18a.parquet
# Processed file: id=4940a214.parquet
# Processed file: id=4950e24c.parquet
# Processed file: id=49a1931d.parquet
# Processed file: id=49e4eade.parquet
# Processed file: id=4a1440d9.parquet
# Processed file: id=4a17b463.parquet
# Processed file: id=4a475a9f.parquet
# Processed file: id=4a4a0f78.parquet
# Processed file: id=4a62661a.parquet
# Processed file: id=4a6af685.parquet
# Processed file: id=4a9f92ca.parquet
# Processed file: id=4aa87859.parquet
# Processed file: id=4b0f961e.parquet
# Processed file: id=4b3c7594.parquet
# Processed file: id=4b71830a.parquet
# Processed file: id=4bc2bee9.parquet
# Processed file: id=4ca242ea.parquet
# Processed file: id=4cabd7aa.parquet
# Processed file: id=4cde1e34.parquet
# Processed file: id=4d19854c.parquet
# Processed file: id=4d5a8ce7.parquet
# Processed file: id=4d61a44e.parquet
# Processed file: id=4dc4ed56.parquet
# Processed file: id=4decbcd8.parquet
# Processed file: id=4dfb4e1d.parquet
# Processed file: id=4e6c7a75.parquet
# Processed file: id=4e85505f.parquet
# Processed file: id=4f059221.parquet
# Processed file: id=4f20b188.parquet
# Processed file: id=4fd7e043.parquet
# Processed file: id=50707f1e.parquet
# Processed file: id=50b2b84b.parquet
# Processed file: id=5124169c.parquet
# Processed file: id=5132511c.parquet
# Processed file: id=51364c23.parquet
# Processed file: id=51f38b37.parquet
# Processed file: id=5264bb0e.parquet
# Processed file: id=526f719b.parquet
# Processed file: id=52ce9b8b.parquet
# Processed file: id=52e9e467.parquet
# Processed file: id=537dc410.parquet
# Processed file: id=53814642.parquet
# Processed file: id=53905a2c.parquet
# Processed file: id=54391716.parquet
# Processed file: id=54945f30.parquet
# Processed file: id=54fef303.parquet
# Processed file: id=554e46e9.parquet
# Processed file: id=55f9338e.parquet
# Processed file: id=563ebc00.parquet
# Processed file: id=56cb7161.parquet
# Processed file: id=56d9dead.parquet
# Processed file: id=56ef356c.parquet
# Processed file: id=5779f2e9.parquet
# Processed file: id=579e50bd.parquet
# Processed file: id=57c4f2b4.parquet
# Processed file: id=57de6095.parquet
# Processed file: id=57f6fa6c.parquet
# Processed file: id=58391429.parquet
# Processed file: id=58ada72e.parquet
# Processed file: id=58dfccdb.parquet
# Processed file: id=5985f299.parquet
# Processed file: id=5a313293.parquet
# Processed file: id=5af79adb.parquet
# Processed file: id=5b2c9b83.parquet
# Processed file: id=5b66b6f2.parquet
# Processed file: id=5b9ff85e.parquet
# Processed file: id=5c186496.parquet
# Processed file: id=5c22f241.parquet
# Processed file: id=5c2c136d.parquet
# Processed file: id=5cd83147.parquet
# Processed file: id=5d3b6ea5.parquet
# Processed file: id=5d762840.parquet
# Processed file: id=5d885b20.parquet
# Processed file: id=5ddbac80.parquet
# Processed file: id=5e359a08.parquet
# Processed file: id=5e55e9fd.parquet
# Processed file: id=5e57bd12.parquet
# Processed file: id=5ea2c305.parquet
# Processed file: id=5ed5f205.parquet
# Processed file: id=5ee595e8.parquet
# Processed file: id=5ef3d64e.parquet
# Processed file: id=5f099188.parquet
# Processed file: id=5f1b07e1.parquet
# Processed file: id=5f37ceb1.parquet
# Processed file: id=5f574f3d.parquet
# Processed file: id=5f7537cf.parquet
# Processed file: id=5f78f7b9.parquet
# Processed file: id=5f9dddb4.parquet
# Processed file: id=60c1ff37.parquet
# Processed file: id=613fc399.parquet
# Processed file: id=6187d0dc.parquet
# Processed file: id=6197a2ce.parquet
# Processed file: id=621066ff.parquet
# Processed file: id=6247cc15.parquet
# Processed file: id=6282e693.parquet
# Processed file: id=62b873a2.parquet
# Processed file: id=62cd5c74.parquet
# Processed file: id=63d4ab9a.parquet
# Processed file: id=63fc9770.parquet
# Processed file: id=641697e6.parquet
# Processed file: id=649ff6d9.parquet
# Processed file: id=64b4005d.parquet
# Processed file: id=64ed48c4.parquet
# Processed file: id=658e66ec.parquet
# Processed file: id=6595d479.parquet
# Processed file: id=659fec57.parquet
# Processed file: id=65fe69c0.parquet
# Processed file: id=6699c999.parquet
# Processed file: id=66f619e3.parquet
# Processed file: id=677038b5.parquet
# Processed file: id=6774ba64.parquet
# Processed file: id=678598dd.parquet
# Processed file: id=6795027a.parquet
# Processed file: id=6826f0be.parquet
# Processed file: id=685cc0f1.parquet
# Processed file: id=687c85e7.parquet
# Processed file: id=68be3d5c.parquet
# Processed file: id=68fa4631.parquet
# Processed file: id=697c41d7.parquet
# Processed file: id=69b65679.parquet
# Processed file: id=6a16089d.parquet
# Processed file: id=6a2fd807.parquet
# Processed file: id=6a4df6ff.parquet
# Processed file: id=6a864b11.parquet
# Processed file: id=6abd21d4.parquet
# Processed file: id=6ac5763a.parquet
# Processed file: id=6ac5eaaf.parquet
# Processed file: id=6b6467f4.parquet
# Processed file: id=6b773506.parquet
# Processed file: id=6c0fe935.parquet
# Processed file: id=6c2edc91.parquet
# Processed file: id=6c6cd633.parquet
# Processed file: id=6c737069.parquet
# Processed file: id=6d5944a9.parquet
# Processed file: id=6d707ac3.parquet
# Processed file: id=6dfe4a75.parquet
# Processed file: id=6e128c6b.parquet
# Processed file: id=6e1d28b6.parquet
# Processed file: id=6e85a624.parquet
# Processed file: id=6e9beaee.parquet
# Processed file: id=6ebfdc95.parquet
# Processed file: id=6f49c8d0.parquet
# Processed file: id=6f5677b7.parquet
# Processed file: id=6fb28c2a.parquet
# Processed file: id=6fcdcb2a.parquet
# Processed file: id=7015528d.parquet
# Processed file: id=709457f3.parquet
# Processed file: id=70de1c63.parquet
# Processed file: id=71850348.parquet
# Processed file: id=71852781.parquet
# Processed file: id=7187caec.parquet
# Processed file: id=71c1b1d2.parquet
# Processed file: id=71ee31f8.parquet
# Processed file: id=721ea536.parquet
# Processed file: id=7265f1e5.parquet
# Processed file: id=72a0c969.parquet
# Processed file: id=72c9c38d.parquet
# Processed file: id=732b2327.parquet
# Processed file: id=7347b54e.parquet
# Processed file: id=73ec551e.parquet
# Processed file: id=73ffa609.parquet
# Processed file: id=745e6065.parquet
# Processed file: id=7494989e.parquet
# Processed file: id=75ad73ee.parquet
# Processed file: id=75b0446f.parquet
# Processed file: id=75b53bd4.parquet
# Processed file: id=75c13e08.parquet
# Processed file: id=764d8b42.parquet
# Processed file: id=76781cd8.parquet
# Processed file: id=76fb4afb.parquet
# Processed file: id=7800a084.parquet
# Processed file: id=7860b64c.parquet
# Processed file: id=78704d22.parquet
# Processed file: id=79bd36b6.parquet
# Processed file: id=7a0136e0.parquet
# Processed file: id=7a6d26a2.parquet
# Processed file: id=7b0a4060.parquet
# Processed file: id=7b543871.parquet
# Processed file: id=7b8842c3.parquet
# Processed file: id=7bdbf66f.parquet
# Processed file: id=7c194077.parquet
# Processed file: id=7c21ad67.parquet
# Processed file: id=7c39c8e5.parquet
# Processed file: id=7ce36c38.parquet
# Processed file: id=7d8f1716.parquet
# Processed file: id=7dc65b92.parquet
# Processed file: id=7e46b693.parquet
# Processed file: id=7e87087b.parquet
# Processed file: id=7f26f78c.parquet
# Processed file: id=7f2715b4.parquet
# Processed file: id=7f44236f.parquet
# Processed file: id=7fa51811.parquet
# Processed file: id=7fa7ccc4.parquet
# Processed file: id=806d877f.parquet
# Processed file: id=8078b7de.parquet
# Processed file: id=807d8908.parquet
# Processed file: id=80b46ffb.parquet
# Processed file: id=812f6873.parquet
# Processed file: id=8148c785.parquet
# Processed file: id=81a4b826.parquet
# Processed file: id=81d3ab22.parquet
# Processed file: id=81feecad.parquet
# Processed file: id=82ec9747.parquet
# Processed file: id=83379672.parquet
# Processed file: id=836b4de3.parquet
# Processed file: id=83711ef5.parquet
# Processed file: id=8376acc5.parquet
# Processed file: id=83846d0c.parquet
# Processed file: id=83912085.parquet
# Processed file: id=83eda373.parquet
# Processed file: id=84875079.parquet
# Processed file: id=84b7d89d.parquet
# Processed file: id=855c6099.parquet
# Processed file: id=857baaa6.parquet
# Processed file: id=85d99199.parquet
# Processed file: id=85d9c915.parquet
# Processed file: id=860f4f9c.parquet
# Processed file: id=86335468.parquet
# Processed file: id=863e40c7.parquet
# Processed file: id=86a8e0d6.parquet
# Processed file: id=86bd716a.parquet
# Processed file: id=87050a09.parquet
# Processed file: id=87af775e.parquet
# Processed file: id=8823b020.parquet
# Processed file: id=8875387b.parquet
# Processed file: id=893293dd.parquet
# Processed file: id=89739b1a.parquet
# Processed file: id=897da2c8.parquet
# Processed file: id=898096eb.parquet
# Processed file: id=89a26502.parquet
# Processed file: id=8a44ea3a.parquet
# Processed file: id=8a4e5d1a.parquet
# Processed file: id=8a645723.parquet
# Processed file: id=8a6b6912.parquet
# Processed file: id=8a77c3e9.parquet
# Processed file: id=8a9e653f.parquet
# Processed file: id=8abbbc38.parquet
# Processed file: id=8ba98f12.parquet
# Processed file: id=8c0ca955.parquet
# Processed file: id=8c1f9196.parquet
# Processed file: id=8c6c52a2.parquet
# Processed file: id=8cab7bc4.parquet
# Processed file: id=8d8b8553.parquet
# Processed file: id=8ddb6b8d.parquet
# Processed file: id=8e59a69a.parquet
# Processed file: id=8e749c85.parquet
# Processed file: id=8e80deb7.parquet
# Processed file: id=8ec2cc63.parquet
# Processed file: id=8f015125.parquet
# Processed file: id=8f21c613.parquet
# Processed file: id=8f2d131f.parquet
# Processed file: id=8f753551.parquet
# Processed file: id=8f9c03c6.parquet
# Processed file: id=90161e10.parquet
# Processed file: id=9027c805.parquet
# Processed file: id=9052579b.parquet
# Processed file: id=9061cc9c.parquet
# Processed file: id=9105b812.parquet
# Processed file: id=9130a22e.parquet
# Processed file: id=913bea9f.parquet
# Processed file: id=91656d27.parquet
# Processed file: id=92293b06.parquet
# Processed file: id=92622443.parquet
# Processed file: id=9271574b.parquet
# Processed file: id=92bb8516.parquet
# Processed file: id=930c567c.parquet
# Processed file: id=93559639.parquet
# Processed file: id=93904b23.parquet
# Processed file: id=93c06d4c.parquet
# Processed file: id=93c72a97.parquet
# Processed file: id=93c93585.parquet
# Processed file: id=93fd93c4.parquet
# Processed file: id=93fda84a.parquet
# Processed file: id=9402b885.parquet
# Processed file: id=948a7025.parquet
# Processed file: id=948e1435.parquet
# Processed file: id=949f94e5.parquet
# Processed file: id=94a1053b.parquet
# Processed file: id=9540fa8e.parquet
# Processed file: id=954a4c2e.parquet
# Processed file: id=9570bfb7.parquet
# Processed file: id=95cc96cc.parquet
# Processed file: id=95d57ff9.parquet
# Processed file: id=966161e7.parquet
# Processed file: id=96de5f57.parquet
# Processed file: id=97bb0cc0.parquet
# Processed file: id=98413061.parquet
# Processed file: id=98ed2153.parquet
# Processed file: id=994ee014.parquet
# Processed file: id=99b15811.parquet
# Processed file: id=9a2082cf.parquet
# Processed file: id=9a5aed6c.parquet
# Processed file: id=9a7e4c38.parquet
# Processed file: id=9aa1a2ae.parquet
# Processed file: id=9ab4909f.parquet
# Processed file: id=9b328d6c.parquet
# Processed file: id=9b96b0e4.parquet
# Processed file: id=9bdd6964.parquet
# Processed file: id=9c1ea003.parquet
# Processed file: id=9cba0d0e.parquet
# Processed file: id=9ce139d3.parquet
# Processed file: id=9cee3c19.parquet
# Processed file: id=9cf04c41.parquet
# Processed file: id=9d0670dd.parquet
# Processed file: id=9d1b2d2c.parquet
# Processed file: id=9d65adbf.parquet
# Processed file: id=9d6b1410.parquet
# Processed file: id=9dc74359.parquet
# Processed file: id=9ddb06db.parquet
# Processed file: id=9ddfb9e6.parquet
# Processed file: id=9e027e04.parquet
# Processed file: id=9e052412.parquet
# Processed file: id=9e171735.parquet
# Processed file: id=9e4385f7.parquet
# Processed file: id=9e964060.parquet
# Processed file: id=9eb283e4.parquet
# Processed file: id=9ebb73c7.parquet
# Processed file: id=9f3ca269.parquet
# Processed file: id=9f70688f.parquet
# Processed file: id=9f9be55c.parquet
# Processed file: id=9fa5cdfd.parquet
# Processed file: id=9fa68512.parquet
# Processed file: id=9fb96ae3.parquet
# Processed file: id=9ff73d95.parquet
# Processed file: id=a00c85e7.parquet
# Processed file: id=a0182b17.parquet
# Processed file: id=a0522c83.parquet
# Processed file: id=a08ebf6e.parquet
# Processed file: id=a148b46f.parquet
# Processed file: id=a1942b0b.parquet
# Processed file: id=a1ab89aa.parquet
# Processed file: id=a221c60c.parquet
# Processed file: id=a26c3e8f.parquet
# Processed file: id=a28c7891.parquet
# Processed file: id=a297d1b9.parquet
# Processed file: id=a2994e55.parquet
# Processed file: id=a302a015.parquet
# Processed file: id=a3391798.parquet
# Processed file: id=a3858c6a.parquet
# Processed file: id=a3b146ca.parquet
# Processed file: id=a3bd8858.parquet
# Processed file: id=a402c6c8.parquet
# Processed file: id=a40c8316.parquet
# Processed file: id=a4481101.parquet
# Processed file: id=a4530b41.parquet
# Processed file: id=a49eda7f.parquet
# Processed file: id=a4e0447e.parquet
# Processed file: id=a4f13c0d.parquet
# Processed file: id=a5078c62.parquet
# Processed file: id=a5099438.parquet
# Processed file: id=a5710c0a.parquet
# Processed file: id=a5974a7d.parquet
# Processed file: id=a5dbb00a.parquet
# Processed file: id=a614af1b.parquet
# Processed file: id=a65b2226.parquet
# Processed file: id=a6969e1a.parquet
# Processed file: id=a6fbb2e7.parquet
# Processed file: id=a774c63b.parquet
# Processed file: id=a7b9546a.parquet
# Processed file: id=a808ad0a.parquet
# Processed file: id=a814e825.parquet
# Processed file: id=a8926a86.parquet
# Processed file: id=a8b0428d.parquet
# Processed file: id=a8c1aab5.parquet
# Processed file: id=a8d9de72.parquet
# Processed file: id=a922ef3f.parquet
# Processed file: id=a95b4487.parquet
# Processed file: id=a9b84b96.parquet
# Processed file: id=a9c53cdb.parquet
# Processed file: id=aa1700c7.parquet
# Processed file: id=aae9800e.parquet
# Processed file: id=aaefeff0.parquet
# Processed file: id=ab16a20d.parquet
# Processed file: id=ab2ad965.parquet
# Processed file: id=ab36aa48.parquet
# Processed file: id=ab54c39e.parquet
# Processed file: id=ab987c75.parquet
# Processed file: id=abac67cc.parquet
# Processed file: id=abaf745c.parquet
# Processed file: id=ac1ad4a7.parquet
# Processed file: id=ac3ba541.parquet
# Processed file: id=ac66c144.parquet
# Processed file: id=ad0bbf35.parquet
# Processed file: id=ad380962.parquet
# Processed file: id=ad536dea.parquet
# Processed file: id=ad9f821d.parquet
# Processed file: id=adaf7461.parquet
# Processed file: id=adba23f0.parquet
# Processed file: id=adbd6839.parquet
# Processed file: id=adc2d620.parquet
# Processed file: id=ae712150.parquet
# Processed file: id=aecc7e74.parquet
# Processed file: id=af485add.parquet
# Processed file: id=af4f064e.parquet
# Processed file: id=b074f33b.parquet
# Processed file: id=b08423c5.parquet
# Processed file: id=b08f0ca4.parquet
# Processed file: id=b120a337.parquet
# Processed file: id=b1de4423.parquet
# Processed file: id=b1f064ac.parquet
# Processed file: id=b23b9220.parquet
# Processed file: id=b25abc27.parquet
# Processed file: id=b2987a65.parquet
# Processed file: id=b2b56219.parquet
# Processed file: id=b308c03e.parquet
# Processed file: id=b37281d5.parquet
# Processed file: id=b3b200af.parquet
# Processed file: id=b3f5c066.parquet
# Processed file: id=b41cee02.parquet
# Processed file: id=b447e66d.parquet
# Processed file: id=b452f767.parquet
# Processed file: id=b4e69f09.parquet
# Processed file: id=b69bf1f7.parquet
# Processed file: id=b712b69b.parquet
# Processed file: id=b7a61f8d.parquet
# Processed file: id=b7c410a9.parquet
# Processed file: id=b802aec3.parquet
# Processed file: id=b823508b.parquet
# Processed file: id=b94ec4a1.parquet
# Processed file: id=b95aad8d.parquet
# Processed file: id=b9b22bff.parquet
# Processed file: id=b9c085ab.parquet
# Processed file: id=b9cf3f7c.parquet
# Processed file: id=b9e90f7f.parquet
# Processed file: id=ba73bc7c.parquet
# Processed file: id=bb0d7d92.parquet
# Processed file: id=bb808a71.parquet
# Processed file: id=bba6ff20.parquet
# Processed file: id=bbd71a7c.parquet
# Processed file: id=bbe5bedd.parquet
# Processed file: id=bc4eaf77.parquet
# Processed file: id=bc66f41d.parquet
# Processed file: id=bc6bd8b2.parquet
# Processed file: id=bd4ccd4c.parquet
# Processed file: id=bd8397cb.parquet
# Processed file: id=bdbff28b.parquet
# Processed file: id=bdcc7d10.parquet
# Processed file: id=be210bc7.parquet
# Processed file: id=bea525dc.parquet
# Processed file: id=bebff291.parquet
# Processed file: id=bf31e0a7.parquet
# Processed file: id=bfb421f9.parquet
# Processed file: id=c00c663c.parquet
# Processed file: id=c0442863.parquet
# Processed file: id=c09d41cd.parquet
# Processed file: id=c0a7d046.parquet
# Processed file: id=c0f2a046.parquet
# Processed file: id=c1373df0.parquet
# Processed file: id=c274a243.parquet
# Processed file: id=c294b507.parquet
# Processed file: id=c2b40d6f.parquet
# Processed file: id=c2e15338.parquet
# Processed file: id=c3061b23.parquet
# Processed file: id=c308b134.parquet
# Processed file: id=c38585c5.parquet
# Processed file: id=c38a5c9b.parquet
# Processed file: id=c3a3f61e.parquet
# Processed file: id=c3a86e3e.parquet
# Processed file: id=c3adae87.parquet
# Processed file: id=c3d46daf.parquet
# Processed file: id=c3dde859.parquet
# Processed file: id=c446e1c5.parquet
# Processed file: id=c45068a1.parquet
# Processed file: id=c4c2076b.parquet
# Processed file: id=c5462e87.parquet
# Processed file: id=c55187b4.parquet
# Processed file: id=c5cfaeae.parquet
# Processed file: id=c6313b18.parquet
# Processed file: id=c6575d38.parquet
# Processed file: id=c6cc7467.parquet
# Processed file: id=c6d4b453.parquet
# Processed file: id=c6da0d4b.parquet
# Processed file: id=c6ead822.parquet
# Processed file: id=c731458f.parquet
# Processed file: id=c73dd2e4.parquet
# Processed file: id=c73f149c.parquet
# Processed file: id=c79039af.parquet
# Processed file: id=c7d9e964.parquet
# Processed file: id=c8270746.parquet
# Processed file: id=c829500d.parquet
# Processed file: id=c8cc2e1b.parquet
# Processed file: id=c8fbbc8a.parquet
# Processed file: id=c9600298.parquet
# Processed file: id=c96b9609.parquet
# Processed file: id=c9879365.parquet
# Processed file: id=c9902f48.parquet
# Processed file: id=c9dabad5.parquet
# Processed file: id=c9e419e7.parquet
# Processed file: id=ca3204b0.parquet
# Processed file: id=ca33a5e7.parquet
# Processed file: id=cadd4ae5.parquet
# Processed file: id=cb2752bc.parquet
# Processed file: id=cb3b7c3c.parquet
# Processed file: id=cb73fed9.parquet
# Processed file: id=cba39753.parquet
# Processed file: id=cbcf8cf2.parquet
# Processed file: id=cd144127.parquet
# Processed file: id=cd1fff5a.parquet
# Processed file: id=cd39e576.parquet
# Processed file: id=cd68643b.parquet
# Processed file: id=cd703872.parquet
# Processed file: id=cd89d5f1.parquet
# Processed file: id=cd8f3c61.parquet
# Processed file: id=cda90e9e.parquet
# Processed file: id=ce379a6a.parquet
# Processed file: id=ce6eeadf.parquet
# Processed file: id=cefdb7fe.parquet
# Processed file: id=cf1b9d44.parquet
# Processed file: id=cfcf9dc9.parquet
# Processed file: id=cfe4cf40.parquet
# Processed file: id=d05f5d71.parquet
# Processed file: id=d08806a2.parquet
# Processed file: id=d0ac4f1c.parquet
# Processed file: id=d19e1025.parquet
# Processed file: id=d28f0d44.parquet
# Processed file: id=d2d9b474.parquet
# Processed file: id=d3da09e8.parquet
# Processed file: id=d445fb74.parquet
# Processed file: id=d4d2f272.parquet
# Processed file: id=d4d9f7f9.parquet
# Processed file: id=d506f4c7.parquet
# Processed file: id=d57f6c9e.parquet
# Processed file: id=d5a8d9b0.parquet
# Processed file: id=d5b089a4.parquet
# Processed file: id=d5fde276.parquet
# Processed file: id=d6251195.parquet
# Processed file: id=d661ddf7.parquet
# Processed file: id=d6776176.parquet
# Processed file: id=d6cca65e.parquet
# Processed file: id=d74e4d7c.parquet
# Processed file: id=d77ac332.parquet
# Processed file: id=d791703f.parquet
# Processed file: id=d8037389.parquet
# Processed file: id=d859115e.parquet
# Processed file: id=d87e2d01.parquet
# Processed file: id=d9c82502.parquet
# Processed file: id=da09ed4b.parquet
# Processed file: id=da19c97e.parquet
# Processed file: id=da5a8921.parquet
# Processed file: id=dacc2f83.parquet
# Processed file: id=daf3969c.parquet
# Processed file: id=db23fbe4.parquet
# Processed file: id=db38d1f9.parquet
# Processed file: id=db3b1dd1.parquet
# Processed file: id=db746de0.parquet
# Processed file: id=db9eae59.parquet
# Processed file: id=dc33dcef.parquet
# Processed file: id=dcfcd574.parquet
# Processed file: id=dd689eb0.parquet
# Processed file: id=dd747bba.parquet
# Processed file: id=de3750cc.parquet
# Processed file: id=de3ecca9.parquet
# Processed file: id=de742c5c.parquet
# Processed file: id=de91310c.parquet
# Processed file: id=df4ab9b1.parquet
# Processed file: id=df556fd2.parquet
# Processed file: id=df98fbb4.parquet
# Processed file: id=e0283d3d.parquet
# Processed file: id=e0655da2.parquet
# Processed file: id=e072b994.parquet
# Processed file: id=e0869709.parquet
# Processed file: id=e0ad6550.parquet
# Processed file: id=e0db55b1.parquet
# Processed file: id=e1958a83.parquet
# Processed file: id=e1a4575f.parquet
# Processed file: id=e1ccc3d1.parquet
# Processed file: id=e1e02e28.parquet
# Processed file: id=e1ea8dd7.parquet
# Processed file: id=e21255e2.parquet
# Processed file: id=e23a8a0a.parquet
# Processed file: id=e243119c.parquet
# Processed file: id=e28c0bfa.parquet
# Processed file: id=e315fdd7.parquet
# Processed file: id=e328a032.parquet
# Processed file: id=e37d000b.parquet
# Processed file: id=e3bce7e1.parquet
# Processed file: id=e3f71f7a.parquet
# Processed file: id=e40319d7.parquet
# Processed file: id=e4614ec6.parquet
# Processed file: id=e46417a7.parquet
# Processed file: id=e4762a2b.parquet
# Processed file: id=e4ab3b12.parquet
# Processed file: id=e4b47411.parquet
# Processed file: id=e4d396d7.parquet
# Processed file: id=e4e58096.parquet
# Processed file: id=e51193d1.parquet
# Processed file: id=e5349ce2.parquet
# Processed file: id=e63000c5.parquet
# Processed file: id=e683d2c9.parquet
# Processed file: id=e7401605.parquet
# Processed file: id=e754411f.parquet
# Processed file: id=e76ad778.parquet
# Processed file: id=e7d08824.parquet
# Processed file: id=e88aa867.parquet
# Processed file: id=e892aec6.parquet
# Processed file: id=e8b64419.parquet
# Processed file: id=e8e82627.parquet
# Processed file: id=e9ca5586.parquet
# Processed file: id=e9d94c4e.parquet
# Processed file: id=ea4619ec.parquet
# Processed file: id=ea544af3.parquet
# Processed file: id=ea7277b4.parquet
# Processed file: id=ea7adcd6.parquet
# Processed file: id=eaab7a96.parquet
# Processed file: id=eb93a46a.parquet
# Processed file: id=ebd6f819.parquet
# Processed file: id=ebf2b0c9.parquet
# Processed file: id=ebf30e46.parquet
# Processed file: id=ec13a1b9.parquet
# Processed file: id=ec6b57b4.parquet
# Processed file: id=ec8f8f95.parquet
# Processed file: id=ec9195be.parquet
# Processed file: id=ecd25dd1.parquet
# Processed file: id=ed0b3906.parquet
# Processed file: id=ed711416.parquet
# Processed file: id=edb9d0f3.parquet
# Processed file: id=ee21612e.parquet
# Processed file: id=ee2bf575.parquet
# Processed file: id=ee67eb55.parquet
# Processed file: id=eeedcd5e.parquet
# Processed file: id=eef79620.parquet
# Processed file: id=ef07f833.parquet
# Processed file: id=ef58dd3c.parquet
# Processed file: id=ef9617e7.parquet
# Processed file: id=efa35d35.parquet
# Processed file: id=f015a18c.parquet
# Processed file: id=f028534c.parquet
# Processed file: id=f0957ca1.parquet
# Processed file: id=f09e7b33.parquet
# Processed file: id=f0d76b32.parquet
# Processed file: id=f1049268.parquet
# Processed file: id=f11e17c0.parquet
# Processed file: id=f1baae47.parquet
# Processed file: id=f1bd0f59.parquet
# Processed file: id=f285b43c.parquet
# Processed file: id=f2d4efd8.parquet
# Processed file: id=f3020788.parquet
# Processed file: id=f32a9580.parquet
# Processed file: id=f35b607c.parquet
# Processed file: id=f4114031.parquet
# Processed file: id=f420b05a.parquet
# Processed file: id=f44f1227.parquet
# Processed file: id=f47a67cc.parquet
# Processed file: id=f47abc42.parquet
# Processed file: id=f4d2f5af.parquet
# Processed file: id=f57de847.parquet
# Processed file: id=f584742f.parquet
# Processed file: id=f5ad7abc.parquet
# Processed file: id=f5b2acf0.parquet
# Processed file: id=f62b317d.parquet
# Processed file: id=f64ae747.parquet
# Processed file: id=f67908e7.parquet
# Processed file: id=f6b719ee.parquet
# Processed file: id=f6c0e2b7.parquet
# Processed file: id=f6c20447.parquet
# Processed file: id=f6cc80a9.parquet
# Processed file: id=f6d6f400.parquet
# Processed file: id=f6d879aa.parquet
# Processed file: id=f74eda33.parquet
# Processed file: id=f75c957f.parquet
# Processed file: id=f7b1374e.parquet
# Processed file: id=f7fc97cf.parquet
# Processed file: id=f81598bf.parquet
# Processed file: id=f8674e15.parquet
# Processed file: id=f869d220.parquet
# Processed file: id=f8bf4a1c.parquet
# Processed file: id=f8ff0bc8.parquet
# Processed file: id=f93010a8.parquet
# Processed file: id=f9334e08.parquet
# Processed file: id=f9384fa2.parquet
# Processed file: id=fa34f945.parquet
# Processed file: id=fa3e1e21.parquet
# Processed file: id=fa633e39.parquet
# Processed file: id=fa9a0add.parquet
# Processed file: id=fab75c2c.parquet
# Processed file: id=fad07fce.parquet
# Processed file: id=fb04f7dd.parquet
# Processed file: id=fb3c2c87.parquet
# Processed file: id=fb9c5a33.parquet
# Processed file: id=fc2c2c08.parquet
# Processed file: id=fc41be2f.parquet
# Processed file: id=fc49ba65.parquet
# Processed file: id=fc8e4de4.parquet
# Processed file: id=fd028ecc.parquet
# Processed file: id=fd0d9bca.parquet
# Processed file: id=fd56e059.parquet
# Processed file: id=fdb6b48b.parquet
# Processed file: id=fdc11b96.parquet
# Processed file: id=fdea7d9e.parquet
# Processed file: id=fdf4691f.parquet
# Processed file: id=fe3cbf02.parquet
# Processed file: id=fe9c71d8.parquet
# Processed file: id=fecc07d6.parquet
# Processed file: id=ff18b749.parquet
# Processed file: id=ffcd4dbd.parquet
# Processed file: id=ffed1dd5.parquet
# Features extracted and saved successfully for all participants.
#      mean_x    mean_y    mean_z     std_x     std_y     std_z  mean_enmo  \
# 0  0.021842  0.022246 -1.019922  0.000338  0.000240  0.001765   0.020411
# 1  0.017524  0.012113 -0.433691  0.446348  0.338916  0.700912   0.013445
# 2  0.217549  0.064164  0.159889  0.507957  0.464649  0.644808   0.029802
# 3 -0.371353 -0.045925 -0.317118  0.504219  0.433393  0.512965   0.035465
# 4  0.023208  0.068822 -0.051804  0.599330  0.513489  0.567990   0.061621
#
#    std_enmo  max_enmo  min_enmo  mean_magnitude  std_magnitude activity_level  \
# 0  0.001761  0.022853  0.018667        1.020398       0.001759         Medium
# 1  0.031016  2.952888  0.000000        0.996000       0.049507         Medium
# 2  0.104216  3.681586  0.000000        0.980751       0.070811            Low
# 3  0.085573  2.506849  0.000000        0.969044       0.082127            Low
# 4  0.202441  6.307294  0.000000        0.966941       0.135903            Low
#
#    inactivity_percentage  non_wear_percentage
# 0               0.000000             0.000000
# 1               3.763106            48.399446
# 2              15.596860            11.175805
# 3               4.349319             0.000000
# 4               8.530412             0.000000

# %%
# Checked the number of rows (participants) in the final features DataFrame
print(f"Number of rows (participants): {final_features.shape[0]}")
# Out:
# Number of rows (participants): 996

# %%
# Path for saving the CSV file (update the path as needed)
csv_output_file = os.path.join(output_directory, "extracted_features_all_participants.csv")

# Saved the final extracted features to a CSV file
final_features.to_csv(csv_output_file, index=False)

# Output the success message
print(f"Features successfully saved as a CSV file at: {csv_output_file}")
# Out:
# Features successfully saved as a CSV file at: C:/Users/Lenovo/OneDrive/Desktop/SEM 2/ml/project/extracted_features\extracted_features_all_participants.csv
